# %% [markdown]
# <a href="https://colab.research.google.com/github/trinayani04/ADMlab/blob/main/lab_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Load dataset from URL (Example: Titanic dataset)
# Updated URL to Kaggle's Titanic dataset
url = 'https://storage.googleapis.com/tf-datasets/titanic/train.csv'
data = pd.read_csv(url)
# Display the first few rows of the dataset
data.head()
# Out:
#    survived     sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0         0    male  22.0                   1      0   7.2500  Third  unknown
# 1         1  female  38.0                   1      0  71.2833  First        C
# 2         1  female  26.0                   0      0   7.9250  Third  unknown
# 3         1  female  35.0                   1      0  53.1000  First        C
# 4         0    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %%
# Display basic information about the dataset
data.info()
# Summary statistics of numerical columns
data.describe()
# Check for missing values
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survived            627 non-null    int64
#  1   sex                 627 non-null    object
#  2   age                 627 non-null    float64
#  3   n_siblings_spouses  627 non-null    int64
#  4   parch               627 non-null    int64
#  5   fare                627 non-null    float64
#  6   class               627 non-null    object
#  7   deck                627 non-null    object
#  8   embark_town         627 non-null    object
#  9   alone               627 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 49.1+ KB
# survived              0
# sex                   0
# age                   0
# n_siblings_spouses    0
# parch                 0
# fare                  0
# class                 0
# deck                  0
# ...

# %%
import pandas as pd

# Corrected URL for the Titanic dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

data = pd.read_csv(url)
data.head()

# Display basic information about the dataset
data.info()
# Summary statistics of numerical columns
data.describe()
# Check for missing values
data.isnull().sum()

# Handling missing values (Impute 'Age' with median, and 'Embarked' with mode)
data['Age'].fillna(data['Age'].median(), inplace=True)
data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)
# Verify that missing values are handled
print(data.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# ...

# %%
# Correlation matrix
# Select only numerical features for correlation analysis
numerical_data = data.select_dtypes(include=['number'])
correlation_matrix = numerical_data.corr()

import seaborn as sns
import matplotlib.pyplot as plt
# Heatmap of correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f',
cbar=True)
plt.title('Correlation Matrix')
plt.show()

# %%
# Scatter plot for Age vs Fare to analyze trends
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Fare', data=data, hue='Survived',
palette='Set1')
plt.title('Age vs Fare: Trend Analysis')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# Distribution plot for Age (visualize outliers and distribution)
plt.figure(figsize=(8, 6))
sns.histplot(data['Age'], bins=30, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot to visualize outliers in Fare
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['Fare'], color='lightcoral')
plt.title('Fare Outliers')
plt.xlabel('Fare')
plt.show()

# %%
# Count plot for Pclass (Passenger class)
plt.figure(figsize=(8, 6))
sns.countplot(x='Pclass', data=data, palette='Set2')
plt.title('Passenger Class Distribution')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.show()
# Count plot for Survived (Survival distribution)
plt.figure(figsize=(8, 6))
sns.countplot(x='Survived', data=data, palette='Set2')
plt.title('Survival Distribution')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-18-247bcb65f992>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Pclass', data=data, palette='Set2')
# <ipython-input-18-247bcb65f992>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=data, palette='Set2')

# %%
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 19.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 25.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 35.9 MB/s eta 0:00:00
# ...
#   Created wheel for ydata-profiling: filename=ydata_profiling-0.0.dev0-py2.py3-none-any.whl size=390960 sha256=aeb7a436cc731b2cd10fe4368158575cd9c184de3623ed08c23fb8cdabd7b608
#   Stored in directory: /tmp/pip-ephem-wheel-cache-twj_oahq/wheels/85/5d/45/8a23c7b77d2023fbc37490b8902f7fdeff5614f65d6e08b6c4
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=b2b0d02a87aa96c32909d4d9d20d6a77972cce7545c88a345c3f050fbcc1e8eb
# ...

# %%
# !pip install --upgrade numba

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Assuming 'data' is your Pandas DataFrame
profile = ProfileReport(data, title="Pandas Profiling Report") # Create the profile object
profile.to_widgets()                                       # Display the report
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-911d6b2cb0ca> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#       3
#       4 # Assuming 'data' is your Pandas DataFrame
#       5 profile = ProfileReport(data, title="Pandas Profiling Report") # Create the profile object
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/controller/pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
# ...
